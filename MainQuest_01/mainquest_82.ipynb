# %% [markdown]
# # 폐렴을 진단해보자

# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings(action='ignore')

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미합니다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요 !!!***!!!
BATCH_SIZE = 32
EPOCHS = 30

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %% [markdown]
# ## 2. 데이터 가져오기

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %%
### val 사이즈에 따라 유동적으로 생략
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
# 정상이미지, 폐렴이미지
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/IM-0450-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person1345_bacteria_3422.jpeg

# %% [markdown]
#  파일 경로에 NORMAL이 있는지 확인하면 정상 이미지를 셀 수 있습니다. 또한, 파일 경로에 PNEUMONIA이 있는지 확인하면 폐렴 이미지도 셀 수 있습니다.

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1070
# Pneumonia images count in training set: 3115

# %% [markdown]
# tf.data 인스턴스를 만들기

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
#라벨만들기
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지 사이즈 통합시키고 줄이기
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
#train, val 셋 만들기
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
#잘 들어갔는지 확인
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
#test set 만들기
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %% [markdown]
#  Augmentation 도입

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
    return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수에 추가되었습니다.
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# ## 3. 데이터 시각화

# %% [markdown]
# 데이터를 보기 위해 먼저, train에 있는 batch 중 첫 번째 배치를 추출합니다. 추출된 배치를 image와 label 데이터 셋으로 나눕니다. 이제 show_batch() 함수를 이용해서 결과 사진을 보겠습니다.

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(4,math.ceil(BATCH_SIZE/4),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# 좌우 반전 확인!

# %% [markdown]
# ## 4. CNN 모델링

# %% [markdown]
# ## ResNet-18

# %%
import tensorflow as tf

# Residual block
def residual_block(x, filters, downsample=False):
    strides = (2, 2) if downsample else (1, 1)
    
    # Identity shortcut connection
    identity = x
    
    # First convolutional layer of the block
    x = tf.keras.layers.Conv2D(filters, 3, strides=strides, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    
    # Second convolutional layer of the block
    x = tf.keras.layers.Conv2D(filters, 3, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    
    # If downsample, adjust the identity size
    if downsample:
        identity = tf.keras.layers.Conv2D(filters, 1, strides=strides, padding='same')(identity)
        identity = tf.keras.layers.BatchNormalization()(identity)
    
    # Add the identity and residual
    x = tf.keras.layers.Add()([x, identity])
    x = tf.keras.layers.Activation('relu')(x)
    
    return x

# ResNet-18 model
def build_resnet18():
    inputs = tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
    
    # Initial convolutional layer
    x = tf.keras.layers.Conv2D(64, 7, strides=(2, 2), padding='same')(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.MaxPool2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)
    
    # Residual blocks
    #Conv2_x
    x = residual_block(x, filters=64)
    x = residual_block(x, filters=64)
    
    #Conv3_x
    x = residual_block(x, filters=128, downsample=True)
    x = residual_block(x, filters=128)
    
    #Conv4_x
    x = residual_block(x, filters=256, downsample=True)
    x = residual_block(x, filters=256)
    
    #Conv5_x
    x = residual_block(x, filters=512, downsample=True)
    x = residual_block(x, filters=512)
    
    # Final layers
    #Average Pooling
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    
    x = tf.keras.layers.Dense(1000, activation='relu')(x)
    x = tf.keras.layers.Dense(1, activation='sigmoid')(x)
    
    model = tf.keras.Model(inputs=inputs, outputs=x)
    return model

# Create the ResNet-18 model
model = build_resnet18()

# Print the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 180, 180, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 90, 90, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 90, 90, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 90, 90, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 45, 45, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 45, 45, 64)   36928       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 45, 45, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 45, 45, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 45, 45, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 45, 45, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 45, 45, 64)   0           batch_normalization_2[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 45, 45, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 45, 45, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 45, 45, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 45, 45, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 45, 45, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 45, 45, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 45, 45, 64)   0           batch_normalization_4[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 45, 45, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 23, 23, 128)  73856       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 23, 23, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 23, 23, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 23, 23, 128)  147584      activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 23, 23, 128)  8320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 23, 23, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 23, 23, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 23, 23, 128)  0           batch_normalization_6[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 23, 23, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 23, 23, 128)  147584      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 23, 23, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 23, 23, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 23, 23, 128)  147584      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 23, 23, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 23, 23, 128)  0           batch_normalization_9[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 23, 23, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 12, 12, 256)  295168      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 12, 12, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 12, 12, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 12, 12, 256)  590080      activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 12, 12, 256)  33024       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 12, 12, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 12, 12, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 12, 12, 256)  0           batch_normalization_11[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 12, 12, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 12, 12, 256)  590080      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 12, 12, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 12, 12, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 12, 12, 256)  590080      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 12, 12, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 12, 12, 256)  0           batch_normalization_14[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 12, 12, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 6, 6, 512)    1180160     activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 6, 6, 512)    2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 6, 6, 512)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 6, 6, 512)    2359808     activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 6, 6, 512)    131584      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 6, 6, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 6, 6, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 6, 6, 512)    0           batch_normalization_16[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 6, 6, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 6, 6, 512)    2359808     activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 6, 6, 512)    2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 6, 6, 512)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 6, 6, 512)    2359808     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 6, 6, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 6, 6, 512)    0           batch_normalization_19[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 6, 6, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           activation_16[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1000)         513000      global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            1001        dense[0][0]
# ==================================================================================================
# Total params: 11,704,913
# Trainable params: 11,695,313
# Non-trainable params: 9,600
# __________________________________________________________________________________________________

# %% [markdown]
# ## 5. 데이터 imbalance 처리

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.96
# Weight for PNEUMONIA: 0.67

# %% [markdown]
# ## 6. 모델 훈련

# %% [markdown]
# 이미지 훈련은 GPU를 사용할 것이기 때문에 먼저 GPU를 선택합니다. 모델은 위에서 만들었던 모델 함수인 build_model()을 model에 선언합니다.
#
# 이미지의 라벨이 두 개밖에 없기 때문에 "binary_cross entropy" loss를 사용합니다. optimizer로 'adam'을 사용합니다.
# 성과에 대해서 측정하기 위한 metrics으로 'accuracy', 'precision', 'recall'을 사용합니다.

# %%
with tf.device('/GPU:0'):
    model = build_resnet18()
    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
#model fit
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/30
# 130/130 [==============================] - 66s 399ms/step - loss: 0.2856 - accuracy: 0.9031 - precision: 0.9616 - recall: 0.9061 - val_loss: 8.5701 - val_accuracy: 0.7383 - val_precision: 0.7383 - val_recall: 1.0000
# Epoch 2/30
# 130/130 [==============================] - 53s 409ms/step - loss: 0.1790 - accuracy: 0.9365 - precision: 0.9790 - recall: 0.9346 - val_loss: 1.3478 - val_accuracy: 0.7393 - val_precision: 0.7377 - val_recall: 1.0000
# Epoch 3/30
# 130/130 [==============================] - 53s 413ms/step - loss: 0.1532 - accuracy: 0.9454 - precision: 0.9809 - recall: 0.9451 - val_loss: 2.6897 - val_accuracy: 0.7305 - val_precision: 0.7305 - val_recall: 1.0000
# Epoch 4/30
# 130/130 [==============================] - 55s 423ms/step - loss: 0.1239 - accuracy: 0.9541 - precision: 0.9850 - recall: 0.9529 - val_loss: 20.4447 - val_accuracy: 0.2705 - val_precision: 1.0000 - val_recall: 0.0027
# Epoch 5/30
# 130/130 [==============================] - 57s 444ms/step - loss: 0.1247 - accuracy: 0.9488 - precision: 0.9829 - recall: 0.9477 - val_loss: 2.0384 - val_accuracy: 0.7480 - val_precision: 0.7440 - val_recall: 1.0000
# Epoch 6/30
# 130/130 [==============================] - 49s 380ms/step - loss: 0.1169 - accuracy: 0.9550 - precision: 0.9847 - recall: 0.9544 - val_loss: 0.4960 - val_accuracy: 0.7979 - val_precision: 0.9964 - val_recall: 0.7270
# Epoch 7/30
# 130/130 [==============================] - 49s 382ms/step - loss: 0.1027 - accuracy: 0.9587 - precision: 0.9876 - recall: 0.9563 - val_loss: 0.2745 - val_accuracy: 0.8643 - val_precision: 0.8516 - val_recall: 0.9867
# Epoch 8/30
# 130/130 [==============================] - 49s 382ms/step - loss: 0.0852 - accuracy: 0.9639 - precision: 0.9907 - recall: 0.9606 - val_loss: 0.0884 - val_accuracy: 0.9658 - val_precision: 0.9709 - val_recall: 0.9826
# Epoch 9/30
# 130/130 [==============================] - 50s 386ms/step - loss: 0.0910 - accuracy: 0.9678 - precision: 0.9882 - recall: 0.9684 - val_loss: 0.3471 - val_accuracy: 0.8828 - val_precision: 1.0000 - val_recall: 0.8400
# Epoch 10/30
# 130/130 [==============================] - 49s 382ms/step - loss: 0.0844 - accuracy: 0.9671 - precision: 0.9897 - recall: 0.9657 - val_loss: 0.2625 - val_accuracy: 0.9023 - val_precision: 0.9985 - val_recall: 0.8682
# Epoch 11/30
# 130/130 [==============================] - 49s 382ms/step - loss: 0.0779 - accuracy: 0.9697 - precision: 0.9902 - recall: 0.9692 - val_loss: 0.1232 - val_accuracy: 0.9609 - val_precision: 0.9958 - val_recall: 0.9509
# Epoch 12/30
# 130/130 [==============================] - 50s 387ms/step - loss: 0.0702 - accuracy: 0.9745 - precision: 0.9921 - recall: 0.9735 - val_loss: 0.0920 - val_accuracy: 0.9688 - val_precision: 0.9637 - val_recall: 0.9947
# Epoch 13/30
# 130/130 [==============================] - 51s 392ms/step - loss: 0.0637 - accuracy: 0.9743 - precision: 0.9927 - recall: 0.9725 - val_loss: 65.8201 - val_accuracy: 0.2627 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/30
# 130/130 [==============================] - 49s 381ms/step - loss: 0.0519 - accuracy: 0.9798 - precision: 0.9944 - recall: 0.9785 - val_loss: 0.0714 - val_accuracy: 0.9736 - val_precision: 0.9973 - val_recall: 0.9668
# Epoch 15/30
# 130/130 [==============================] - 50s 386ms/step - loss: 0.0528 - accuracy: 0.9781 - precision: 0.9940 - recall: 0.9762 - val_loss: 0.0949 - val_accuracy: 0.9629 - val_precision: 0.9944 - val_recall: 0.9545
# Epoch 16/30
# 130/130 [==============================] - 48s 373ms/step - loss: 0.0564 - accuracy: 0.9774 - precision: 0.9931 - recall: 0.9765 - val_loss: 0.3713 - val_accuracy: 0.9092 - val_precision: 0.8898 - val_recall: 1.0000
# Epoch 17/30
# 130/130 [==============================] - 50s 389ms/step - loss: 0.0401 - accuracy: 0.9820 - precision: 0.9957 - recall: 0.9800 - val_loss: 0.1053 - val_accuracy: 0.9736 - val_precision: 0.9715 - val_recall: 0.9934
# Epoch 18/30
# 130/130 [==============================] - 49s 382ms/step - loss: 0.0486 - accuracy: 0.9796 - precision: 0.9941 - recall: 0.9783 - val_loss: 0.1793 - val_accuracy: 0.9434 - val_precision: 0.9986 - val_recall: 0.9238
# Epoch 19/30
# 130/130 [==============================] - 50s 385ms/step - loss: 0.0457 - accuracy: 0.9825 - precision: 0.9958 - recall: 0.9807 - val_loss: 0.0612 - val_accuracy: 0.9736 - val_precision: 0.9866 - val_recall: 0.9774
# Epoch 20/30
# 130/130 [==============================] - 50s 386ms/step - loss: 0.0389 - accuracy: 0.9865 - precision: 0.9967 - recall: 0.9851 - val_loss: 0.0904 - val_accuracy: 0.9746 - val_precision: 0.9945 - val_recall: 0.9706
# Epoch 21/30
# 130/130 [==============================] - 50s 385ms/step - loss: 0.0303 - accuracy: 0.9882 - precision: 0.9971 - recall: 0.9872 - val_loss: 6.1167 - val_accuracy: 0.4004 - val_precision: 1.0000 - val_recall: 0.1802
# Epoch 22/30
# 130/130 [==============================] - 50s 386ms/step - loss: 0.0419 - accuracy: 0.9849 - precision: 0.9964 - recall: 0.9832 - val_loss: 17.0374 - val_accuracy: 0.2705 - val_precision: 1.0000 - val_recall: 0.0066
# Epoch 23/30
# 130/130 [==============================] - 50s 390ms/step - loss: 0.0367 - accuracy: 0.9873 - precision: 0.9974 - recall: 0.9854 - val_loss: 0.2305 - val_accuracy: 0.9111 - val_precision: 1.0000 - val_recall: 0.8796
# Epoch 24/30
# 130/130 [==============================] - 49s 382ms/step - loss: 0.0491 - accuracy: 0.9791 - precision: 0.9931 - recall: 0.9787 - val_loss: 0.1321 - val_accuracy: 0.9473 - val_precision: 0.9808 - val_recall: 0.9470
# Epoch 25/30
# 130/130 [==============================] - 51s 392ms/step - loss: 0.0348 - accuracy: 0.9880 - precision: 0.9964 - recall: 0.9875 - val_loss: 5.7009 - val_accuracy: 0.3730 - val_precision: 1.0000 - val_recall: 0.1497
# Epoch 26/30
# 130/130 [==============================] - 50s 383ms/step - loss: 0.0405 - accuracy: 0.9846 - precision: 0.9948 - recall: 0.9845 - val_loss: 0.7262 - val_accuracy: 0.8242 - val_precision: 1.0000 - val_recall: 0.7600
# Epoch 27/30
# 130/130 [==============================] - 49s 376ms/step - loss: 0.0321 - accuracy: 0.9887 - precision: 0.9971 - recall: 0.9877 - val_loss: 9.6428 - val_accuracy: 0.3867 - val_precision: 1.0000 - val_recall: 0.1627
# Epoch 28/30
# 130/130 [==============================] - 49s 380ms/step - loss: 0.0255 - accuracy: 0.9889 - precision: 0.9967 - recall: 0.9884 - val_loss: 0.0722 - val_accuracy: 0.9766 - val_precision: 0.9932 - val_recall: 0.9746ss: 0.0280 - accuracy: 0.9878 - precision: 0.9961 - recall: 0.98 - ETA: 5s - los
# Epoch 29/30
# 130/130 [==============================] - 48s 373ms/step - loss: 0.0260 - accuracy: 0.9911 - precision: 0.9974 - recall: 0.9906 - val_loss: 0.0888 - val_accuracy: 0.9619 - val_precision: 0.9611 - val_recall: 0.9880
# Epoch 30/30
# 130/130 [==============================] - 49s 378ms/step - loss: 0.0263 - accuracy: 0.9897 - precision: 0.9967 - recall: 0.9893 - val_loss: 0.1650 - val_accuracy: 0.9492 - val_precision: 0.9986 - val_recall: 0.9321

# %% [markdown]
# ## 7. 결과 확인

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
#테스트 데이터
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 20/20 [==============================] - 5s 228ms/step - loss: 0.9307 - accuracy: 0.8221 - precision: 0.7864 - recall: 0.9821
# Loss: 0.9307398796081543,
# Accuracy: 0.8221153616905212,
# Precision: 0.7864476442337036,
# Recall: 0.9820512533187866
